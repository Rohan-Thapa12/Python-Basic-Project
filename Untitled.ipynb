# %%
student = {}

while True:
    print("--Student Mangement App--")
    print("1. Add Student")
    print("2. View Student")
    print("3. Check Result")
    print("4. Exit")

    ## choice 
    choice = input("Enter the choice you want to see")

    if choice == "1":
        name = input("Enter the student name :")
        marks = input("Enter marks :")
        address = input("Enter the address :")
        student[name] = marks
        print(f" {name} Student Successfully added")

    elif choice == "2":
        if not student:
            print("Student not found")

        else:
            for name, marks in student.items():
                print(name, ":", marks)

    elif choice == "3":
        name = input("Student name")

        if name in student:
            marks = student[name]

            if marks >= "40":
                print("PASS")

            else:
                print("Fail")
        else:
            print("Student not found")

    elif choice == "4":
        print("Exiting .......")
        break;

    else :
        print("Invalid number")
# Out:
# --Student Mangement App--
# 1. Add Student
# 2. View Student
# 3. Check Result
# 4. Exit
# Enter the choice you want to see Rohan Thapa
# Invalid number
# --Student Mangement App--
# 1. Add Student
# 2. View Student
# 3. Check Result
# 4. Exit
# Enter the choice you want to see 1
# Enter the student name : Rohan Thapa
# Enter marks : 99
# Enter the address : Kathmandu
#  Rohan Thapa Student Successfully added
# --Student Mangement App--
# 1. Add Student
# 2. View Student
# 3. Check Result
# 4. Exit
# Enter the choice you want to see 2
# Rohan Thapa : 99
# --Student Mangement App--
# 1. Add Student
# 2. View Student
# 3. Check Result
# 4. Exit
# Enter the choice you want to see 3
# Student name Rohan Thapa
# PASS
# --Student Mangement App--
# 1. Add Student
# 2. View Student
# 3. Check Result
# 4. Exit
# Enter the choice you want to see 4
# Exiting .......
